# %% [markdown]
# # Train/Test Split CV
#
# Generates cross-validation data splits for the dataset.

# %%
import pandas as pd
import numpy as np
import os

# %%
dataset = "Analgesics-induced_acute_liver_failure"
df = pd.read_csv(os.path.join("/home/hsdslab/Documents/Csabi/Pharma_crossval/DeepCausalPV-master-main/dat",dataset, "proc","df_together.csv"), index_col=0)

df2 = pd.DataFrame()
df2.index = df.index
df2["SPLIT"] = np.random.randint(0, 5, df.shape[0])
df2.to_csv(os.path.join("/home/hsdslab/Documents/Csabi/Pharma_crossval/DeepCausalPV-master-main/dat",dataset, "proc","split.csv"))
